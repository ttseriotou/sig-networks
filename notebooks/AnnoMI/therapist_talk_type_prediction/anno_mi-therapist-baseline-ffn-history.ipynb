# %%
import numpy as np
import pickle
import os

seed = 2023

# %%
from nlpsig_networks.scripts.ffn_baseline_functions import (
    histories_baseline_hyperparameter_search
)

# %%
output_dir = "therapist_talk_type_output"
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# ## AnnoMI

# %%
# %run ../load_anno_mi.py

# %%
anno_mi.head()
# Out:
#   mi_quality  transcript_id                         topic  utterance_id  \
# 0       high              0  reducing alcohol consumption             0
# 1       high              0  reducing alcohol consumption             1
# 2       high              0  reducing alcohol consumption             2
# 3       high              0  reducing alcohol consumption             3
# 4       high              0  reducing alcohol consumption             4
#
#   interlocutor timestamp                                     utterance_text  \
# 0    therapist  00:00:13  Thanks for filling it out. We give this form t...
# 1       client  00:00:24                                              Sure.
# 2    therapist  00:00:25  So, let's see. It looks that you put-- You dri...
# 3       client  00:00:34                                            Mm-hmm.
# 4    therapist  00:00:34  -and you usually have three to four drinks whe...
#
#    annotator_id therapist_input_exists therapist_input_subtype  \
# 0             3                  False                     NaN
# 1             3                    NaN                     NaN
# 2             3                   True             information
# 3             3                    NaN                     NaN
# 4             3                   True             information
#
#   reflection_exists reflection_subtype question_exists question_subtype  \
# 0             False                NaN            True             open
# 1               NaN                NaN             NaN              NaN
# 2             False                NaN           False              NaN
# 3               NaN                NaN             NaN              NaN
# 4             False                NaN           False              NaN
#
#   main_therapist_behaviour client_talk_type            datetime
# 0                 question              NaN 2023-07-27 00:00:13
# 1                      NaN          neutral 2023-07-27 00:00:24
# 2          therapist_input              NaN 2023-07-27 00:00:25
# 3                      NaN          neutral 2023-07-27 00:00:34
# 4          therapist_input              NaN 2023-07-27 00:00:34

# %%
with open("../anno_mi_sbert.pkl", "rb") as f:
    sbert_embeddings = pickle.load(f)
    
sbert_embeddings.shape
# Out:
# (13551, 384)

# %% [markdown]
# # Baseline: Averaging history and use FFN
#
# Here, we average the full history of a path and concatenate it the current embedding (the total number of features that are passed into the FFN is `2 * sbert_embeddings.shape[0]`).
#
# Here, we will run the hyperparameter search to implement the FFN with the same parameters as the standard FFN baseline on the sentence embeddings. Going to try out some variations (1 hidden layer, 2 hidden layers and 3 hidden layers - all of size 100).

# %%
num_epochs = 100
hidden_dim_sizes = [[64,64],[128,128],[256,256],[512,512]]
dropout_rates = [0.5, 0.1]
learning_rates = [1e-3, 1e-4, 5e-4]
seeds = [1, 12, 123]
loss = "focal"
gamma = 2
validation_metric = "f1"
patience = 5

# %%
ffn_mean_history, best_ffn_mean_history, _, __ = histories_baseline_hyperparameter_search(
    num_epochs=num_epochs,
    df=anno_mi,
    id_column="transcript_id",
    label_column="main_therapist_behaviour",
    embeddings=sbert_embeddings,
    y_data=y_data_therapist,
    output_dim=output_dim_therapist,
    hidden_dim_sizes=hidden_dim_sizes,
    dropout_rates=dropout_rates,
    learning_rates=learning_rates,
    use_signatures=False,
    seeds=seeds,
    loss=loss,
    gamma=gamma,
    path_indices=therapist_index,
    split_ids=therapist_transcript_id,
    k_fold=False,
    patience=patience,
    validation_metric=validation_metric,
    results_output=f"{output_dir}/ffn_mean_history_focal_{gamma}.csv",
    verbose=False
)
# Out:
# [INFO] Concatenating the embeddings to the dataframe...
# [INFO] - columns beginning with 'e' denote the full embddings.
# [INFO] Adding time feature columns into dataframe in `.df`.
# [INFO] Adding 'time_encoding' and feature...
# [INFO] Adding 'time_diff' and feature...
# [INFO] Adding 'timeline_index' feature...
# Computing the mean history for each item in the dataframe
#   0%|          | 0/13551 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# [INFO] Concatenating the embeddings to the dataframe...
# [INFO] - columns beginning with 'e' denote the full embddings.
# [INFO] Adding time feature columns into dataframe in `.df`.
# [INFO] Adding 'time_encoding' and feature...
# [INFO] Adding 'time_diff' and feature...
# [INFO] Adding 'timeline_index' feature...
# Computing the mean history for each item in the dataframe
#   0%|          | 0/13551 [00:00<?, ?it/s]
# saving results dataframe to CSV for this hyperparameter search in therapist_talk_type_output/ffn_mean_history_focal_2.csv
# saving the best model results dataframe to CSV for this hyperparameter search in therapist_talk_type_output/ffn_mean_history_focal_2_best_model.csv

# %%
ffn_mean_history
# Out:
#         loss  accuracy        f1  \
# 0   0.703645  0.765101  0.732532
# 0   0.755611  0.776286  0.751284
# 0   0.692211  0.753915  0.712624
# 0   0.678555  0.757644  0.723916
# 0   0.695901  0.766592  0.732357
# ..       ...       ...       ...
# 0   0.710750  0.750932  0.716124
# 0   0.695115  0.764355  0.735397
# 0   0.722081  0.750932  0.721820
# 0   0.713407  0.757644  0.720996
# 0   0.685482  0.760626  0.735682
#
#                                             f1_scores  precision  \
# 0   [0.8179723502304148, 0.5615141955835962, 0.684...   0.748203
# 0   [0.8149038461538461, 0.608955223880597, 0.7033...   0.762718
# 0   [0.8026315789473685, 0.5032679738562091, 0.679...   0.730674
# 0   [0.7986270022883296, 0.5313432835820896, 0.700...   0.732329
# 0   [0.8153153153153153, 0.5555555555555555, 0.689...   0.743155
# ..                                                ...        ...
# 0   [0.7955555555555555, 0.5286624203821656, 0.680...   0.734327
# 0   [0.8031145717463848, 0.5779036827195468, 0.696...   0.738695
# 0   [0.7897934386391252, 0.562691131498471, 0.6837...   0.733938
# 0   [0.7977011494252874, 0.5206349206349207, 0.698...   0.736296
# 0   [0.7959413754227733, 0.5869565217391305, 0.696...   0.738010
#
#                                      precision_scores    recall  \
# 0   [0.8255813953488372, 0.6544117647058824, 0.620...  0.726812
# 0   [0.8604060913705583, 0.6623376623376623, 0.626...  0.748607
# 0   [0.7721518987341772, 0.616, 0.6356382978723404...  0.706207
# 0   [0.8004587155963303, 0.577922077922078, 0.6428...  0.721119
# 0   [0.8044444444444444, 0.6293706293706294, 0.647...  0.727206
# ..                                                ...       ...
# 0   [0.7748917748917749, 0.6240601503759399, 0.619...  0.709715
# 0   [0.7830802603036876, 0.5930232558139535, 0.684...  0.733165
# 0   [0.8441558441558441, 0.6301369863013698, 0.612...  0.719290
# 0   [0.8032407407407407, 0.6119402985074627, 0.628...  0.716663
# 0   [0.7861915367483296, 0.5775401069518716, 0.668...  0.735777
#
#                                         recall_scores  valid_loss  \
# 0   [0.8105022831050228, 0.49171270718232046, 0.76...    0.757242
# 0   [0.773972602739726, 0.56353591160221, 0.801223...    0.822343
# 0   [0.8356164383561644, 0.425414364640884, 0.7308...    0.720180
# 0   [0.7968036529680366, 0.49171270718232046, 0.77...    0.722930
# 0   [0.8264840182648402, 0.4972375690607735, 0.737...    0.741430
# ..                                                ...         ...
# 0   [0.817351598173516, 0.4585635359116022, 0.7553...    0.748978
# 0   [0.8242009132420092, 0.56353591160221, 0.70948...    0.750000
# 0   [0.7420091324200914, 0.5082872928176796, 0.773...    0.749692
# 0   [0.7922374429223744, 0.4530386740331492, 0.785...    0.748313
# 0   [0.8059360730593608, 0.5966850828729282, 0.727...    0.745891
#
#     valid_accuracy  ...  dropout_rate learning_rate  seed loss_function  \
# 0         0.719216  ...           0.5        0.0010     0         focal
# 0         0.713619  ...           0.5        0.0010     1         focal
# 0         0.721082  ...           0.5        0.0010    12         focal
# 0         0.723881  ...           0.5        0.0010   123         focal
# 0         0.713619  ...           0.5        0.0010  1234         focal
# ..             ...  ...           ...           ...   ...           ...
# 0         0.724813  ...           0.1        0.0005     0         focal
# 0         0.714552  ...           0.1        0.0005     1         focal
# 0         0.716418  ...           0.1        0.0005    12         focal
# 0         0.720149  ...           0.1        0.0005   123         focal
# 0         0.708022  ...           0.1        0.0005  1234         focal
#
#     gamma k_fold n_splits  batch_size  model_id  input_dim
# 0       2  False     None          64      0.00        768
# 0       2  False     None          64      0.00        768
# 0       2  False     None          64      0.00        768
# 0       2  False     None          64      0.00        768
# 0       2  False     None          64      0.00        768
# ..    ...    ...      ...         ...       ...        ...
# 0       2  False     None          64      0.26        768
# 0       2  False     None          64      0.26        768
# 0       2  False     None          64      0.26        768
# 0       2  False     None          64      0.26        768
# 0       2  False     None          64      0.26        768
#
# [135 rows x 27 columns]

# %%
ffn_mean_history.groupby(["hidden_dim", "dropout_rate", "learning_rate"]).mean()
# Out:
# /var/folders/l7/bnn1j6bs3bqfskq2jlq55yh80000gr/T/ipykernel_42329/1445575783.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ffn_mean_history.groupby(["hidden_dim", "dropout_rate", "learning_rate"]).mean()
#                                            loss  accuracy        f1  \
# hidden_dim dropout_rate learning_rate
# (128, 128) 0.1          0.0001         0.722813  0.768829  0.737768
#                         0.0005         0.700667  0.753766  0.723807
#                         0.0010         0.707521  0.755854  0.722674
#            0.2          0.0001         0.730573  0.767934  0.737488
#                         0.0005         0.698215  0.754959  0.723617
#                         0.0010         0.699787  0.755854  0.724760
#            0.5          0.0001         0.752733  0.764057  0.728949
#                         0.0005         0.688535  0.764653  0.733256
#                         0.0010         0.705185  0.763908  0.730543
# (256, 256) 0.1          0.0001         0.705543  0.757196  0.725568
#                         0.0005         0.709443  0.758091  0.725803
#                         0.0005           2.0     0.0        64.0      0.23
#                         0.0010           2.0     0.0        64.0      0.21
#            0.5          0.0001           2.0     0.0        64.0      0.19
#                         0.0005           2.0     0.0        64.0      0.20
#                         0.0010           2.0     0.0        64.0      0.18
#
#                                        input_dim
# hidden_dim dropout_rate learning_rate
# (128, 128) 0.1          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0
#            0.2          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0
#            0.5          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0
# (256, 256) 0.1          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0
#            0.2          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0
#            0.5          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0
# (512, 512) 0.1          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0
#            0.2          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0
#            0.5          0.0001             768.0
#                         0.0005             768.0
#                         0.0010             768.0

# %%
best_ffn_mean_history
# Out:
#        loss  accuracy        f1  \
# 0  0.701060  0.759135  0.727361
# 0  0.697738  0.761372  0.731740
# 0  0.708779  0.746458  0.714027
# 0  0.698313  0.759135  0.727455
# 0  0.723070  0.764355  0.737554
#
#                                            f1_scores  precision  \
# 0  [0.8017334777898157, 0.5660377358490566, 0.679...   0.744021
# 0  [0.8133640552995393, 0.56797583081571, 0.68125...   0.743574
# 0  [0.7862857142857144, 0.5353846153846153, 0.679...   0.725890
# 0  [0.7986577181208054, 0.555223880597015, 0.6916...   0.735460
# 0  [0.8088578088578088, 0.5868263473053892, 0.692...   0.748460
#
#                                     precision_scores    recall  \
# 0  [0.7628865979381443, 0.656934306569343, 0.6438...  0.719591
# 0  [0.8209302325581396, 0.6266666666666667, 0.616...  0.727381
# 0  [0.7871853546910755, 0.6041666666666666, 0.619...  0.709649
# 0  [0.7828947368421053, 0.6038961038961039, 0.653...  0.723301
# 0  [0.8261904761904761, 0.6405228758169934, 0.624...  0.733937
#
#                                        recall_scores  valid_loss  \
# 0  [0.8447488584474886, 0.4972375690607735, 0.718...    0.739506
# 0  [0.8059360730593608, 0.5193370165745856, 0.761...    0.733883
# 0  [0.7853881278538812, 0.48066298342541436, 0.75...    0.739779
# 0  [0.815068493150685, 0.5138121546961326, 0.7339...    0.758043
# 0  [0.7922374429223744, 0.5414364640883977, 0.776...    0.771632
#
#    valid_accuracy  ...  hidden_dim dropout_rate  learning_rate  seed  \
# 0        0.723881  ...  (512, 512)          0.2         0.0001     0
# 0        0.720149  ...  (512, 512)          0.2         0.0001     1
# 0        0.722948  ...  (512, 512)          0.2         0.0001    12
# 0        0.724813  ...  (512, 512)          0.2         0.0001   123
# 0        0.717351  ...  (512, 512)          0.2         0.0001  1234
#
#    loss_function gamma k_fold  n_splits  batch_size  input_dim
# 0          focal     2  False      None          64        768
# 0          focal     2  False      None          64        768
# 0          focal     2  False      None          64        768
# 0          focal     2  False      None          64        768
# 0          focal     2  False      None          64        768
#
# [5 rows x 26 columns]

# %%
best_ffn_mean_history["f1"].mean()
# Out:
# 0.7276275253985091

# %%
best_ffn_mean_history["precision"].mean()
# Out:
# 0.7394812350515159

# %%
best_ffn_mean_history["recall"].mean()
# Out:
# 0.7227720072768336

# %%
np.stack(best_ffn_mean_history["f1_scores"]).mean(axis=0)
# Out:
# array([0.80177975, 0.56228968, 0.68474961, 0.86169105])

# %%
np.stack(best_ffn_mean_history["precision_scores"]).mean(axis=0)
# Out:
# array([0.79601748, 0.62643732, 0.63156984, 0.9039003 ])

# %%
np.stack(best_ffn_mean_history["recall_scores"]).mean(axis=0)
# Out:
# array([0.8086758 , 0.51049724, 0.74862385, 0.82329114])

# %% [markdown]
# ## KFold
#
# We can repeat this but use K-Fold evaluation instead - by default, we have $K=5$ folds.

# %%
ffn_mean_history_kfold, best_ffn_mean_history_kfold, _, __ = histories_baseline_hyperparameter_search(
    num_epochs=num_epochs,
    df=anno_mi,
    id_column="transcript_id",
    label_column="main_therapist_behaviour",
    embeddings=sbert_embeddings,
    y_data=y_data_therapist,
    output_dim=output_dim_therapist,
    hidden_dim_sizes=hidden_dim_sizes,
    dropout_rates=dropout_rates,
    learning_rates=learning_rates,
    use_signatures=False,
    seeds=seeds,
    loss=loss,
    gamma=gamma,
    path_indices=therapist_index,
    split_ids=therapist_transcript_id,
    k_fold=True,
    patience=patience,
    validation_metric=validation_metric,
    results_output=f"{output_dir}/ffn_mean_history_focal_{gamma}_kfold.csv",
    verbose=False
)
# Out:
# [INFO] Concatenating the embeddings to the dataframe...
# [INFO] - columns beginning with 'e' denote the full embddings.
# [INFO] Adding time feature columns into dataframe in `.df`.
# [INFO] Adding 'time_encoding' and feature...
# [INFO] Adding 'time_diff' and feature...
# [INFO] Adding 'timeline_index' feature...
# Computing the mean history for each item in the dataframe
#   0%|          | 0/13551 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# [INFO] Concatenating the embeddings to the dataframe...
# [INFO] - columns beginning with 'e' denote the full embddings.
# [INFO] Adding time feature columns into dataframe in `.df`.
# [INFO] Adding 'time_encoding' and feature...
# [INFO] Adding 'time_diff' and feature...
# [INFO] Adding 'timeline_index' feature...
# Computing the mean history for each item in the dataframe
#   0%|          | 0/13551 [00:00<?, ?it/s]
# saving results dataframe to CSV for this hyperparameter search in therapist_talk_type_output/ffn_mean_history_focal_2_kfold.csv
# saving the best model results dataframe to CSV for this hyperparameter search in therapist_talk_type_output/ffn_mean_history_focal_2_kfold_best_model.csv

# %%
ffn_mean_history_kfold
# Out:
#     loss  accuracy        f1  \
# 0   None  0.727259  0.705419
# 0   None  0.729522  0.707497
# 0   None  0.735556  0.711041
# 0   None  0.726505  0.703808
# 0   None  0.729069  0.706646
# ..   ...       ...       ...
# 0   None  0.726052  0.701506
# 0   None  0.718811  0.695878
# 0   None  0.721677  0.700205
# 0   None  0.718057  0.694801
# 0   None  0.723639  0.700271
#
#                                             f1_scores  precision  \
# 0   [0.7542566709021601, 0.5554445554445554, 0.651...   0.705466
# 0   [0.7501933488012374, 0.5598356445814072, 0.657...   0.708235
# 0   [0.7587421383647798, 0.5562700964630224, 0.665...   0.712851
# 0   [0.7551020408163265, 0.5518630412890231, 0.649...   0.703853
# 0   [0.7531925983841543, 0.5547226386806596, 0.655...   0.706341
# ..                                                ...        ...
# 0   [0.7506453278265359, 0.5434782608695651, 0.657...   0.701417
# 0   [0.7376212353241449, 0.5438775510204081, 0.650...   0.695649
# 0   [0.7469688982604112, 0.5463367297428432, 0.649...   0.700464
# 0   [0.7454401268834258, 0.5306122448979592, 0.643...   0.696244
# 0   [0.7449032932566649, 0.54293059125964, 0.65729...   0.701310
#
#                                      precision_scores    recall  \
# 0   [0.7669250645994832, 0.5220657276995305, 0.633...  0.707718
# 0   [0.7743480574773816, 0.5396039603960396, 0.626...  0.708754
# 0   [0.7635443037974684, 0.5586652314316469, 0.639...  0.710182
# 0   [0.79198682766191, 0.5224022878932316, 0.62332...  0.706213
# 0   [0.7866086009798585, 0.5216165413533834, 0.632...  0.709459
# ..                                                ...       ...
# 0   [0.775880469583778, 0.5276381909547738, 0.6352...  0.702726
# 0   [0.7533889468196038, 0.5210166177908113, 0.631...  0.697445
# 0   [0.7898550724637681, 0.5008896797153025, 0.624...  0.704273
# 0   [0.7908020190689848, 0.49720149253731344, 0.60...  0.697213
# 0   [0.78039430449069, 0.5238095238095238, 0.62277...  0.701655
#
#                                         recall_scores valid_loss  \
# 0   [0.742, 0.5933831376734259, 0.6713368359603036...       None
# 0   [0.7275, 0.5816435432230523, 0.690601284296555...       None
# 0   [0.754, 0.5538954108858057, 0.6935201401050788...       None
# 0   [0.7215, 0.5848452508004269, 0.677174547577349...       None
# 0   [0.7225, 0.5923159018143009, 0.680677174547577...       None
# ..                                                ...        ...
# 0   [0.727, 0.5602988260405549, 0.681260945709282,...       None
# 0   [0.7225, 0.5688367129135539, 0.670753064798599...       None
# 0   [0.7085, 0.6008537886872999, 0.676007005253940...       None
# 0   [0.705, 0.5688367129135539, 0.681260945709282,...       None
# 0   [0.7125, 0.5635005336179295, 0.695855224751897...       None
#
#     valid_accuracy  ...  dropout_rate learning_rate  seed loss_function  \
# 0         0.789711  ...           0.5        0.0010     0         focal
# 0         0.791143  ...           0.5        0.0010     1         focal
# 0         0.793567  ...           0.5        0.0010    12         focal
# 0         0.786847  ...           0.5        0.0010   123         focal
# 0         0.790372  ...           0.5        0.0010  1234         focal
# ..             ...  ...           ...           ...   ...           ...
# 0         0.783432  ...           0.1        0.0005     0         focal
# 0         0.786407  ...           0.1        0.0005     1         focal
# 0         0.788390  ...           0.1        0.0005    12         focal
# 0         0.786627  ...           0.1        0.0005   123         focal
# 0         0.787729  ...           0.1        0.0005  1234         focal
#
#     gamma k_fold n_splits  batch_size  model_id  input_dim
# 0       2   True        5          64      0.00        768
# 0       2   True        5          64      0.00        768
# 0       2   True        5          64      0.00        768
# 0       2   True        5          64      0.00        768
# 0       2   True        5          64      0.00        768
# ..    ...    ...      ...         ...       ...        ...
# 0       2   True        5          64      0.26        768
# 0       2   True        5          64      0.26        768
# 0       2   True        5          64      0.26        768
# 0       2   True        5          64      0.26        768
# 0       2   True        5          64      0.26        768
#
# [135 rows x 27 columns]

# %%
ffn_mean_history_kfold.groupby(["hidden_dim", "dropout_rate", "learning_rate"]).mean()
# Out:
# /var/folders/l7/bnn1j6bs3bqfskq2jlq55yh80000gr/T/ipykernel_42329/2776369505.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ffn_mean_history_kfold.groupby(["hidden_dim", "dropout_rate", "learning_rate"]).mean()
#                                        accuracy        f1  precision  \
# hidden_dim dropout_rate learning_rate
# (128, 128) 0.1          0.0001         0.728737  0.705350   0.704977
#                         0.0005         0.723096  0.699377   0.699310
#                         0.0010         0.722432  0.699372   0.699523
#            0.2          0.0001         0.729220  0.705507   0.705322
#                         0.0005         0.726173  0.702546   0.702109
#                         0.0010         0.726354  0.703069   0.703390
#            0.5          0.0001         0.732810  0.709314   0.708618
#                         0.0005         0.729099  0.705419   0.705742
#                         0.0010         0.729582  0.706882   0.707349
# (256, 256) 0.1          0.0001         0.727712  0.704915   0.704552
#                         0.0005         0.719867  0.697139   0.696834
#                         0.0010         0.723578  0.700175   0.701027
#            0.2          0.0001         0.727229  0.704385   0.704227
#                         0.0005         0.723065  0.700459   0.699882
#                         0.0010         0.724513  0.701464   0.703447
#            0.5          0.0001         0.730819  0.707406   0.706981
#                         0.0005         0.729280  0.706234   0.706468
#                         0.0010         0.727380  0.704432   0.704647
# (512, 512) 0.1          0.0001         0.727108  0.703889   0.704096
#                         0.0005         0.721647  0.698532   0.699017
#                         0.0010         0.721708  0.697704   0.699159
#            0.2          0.0001         0.726927  0.704072   0.703993
#                         0.0005         0.723367  0.699937   0.701294
#                         0.0010         0.720440  0.696420   0.698202
#            0.5          0.0001         0.730306  0.707402   0.707147
#                         0.0005         0.728647  0.705911   0.705907
#                         0.0010         0.729461  0.705945   0.706299
#
#                                          recall  valid_accuracy  valid_f1  \
# hidden_dim dropout_rate learning_rate
# (128, 128) 0.1          0.0001         0.707955        0.785393  0.770517
#                         0.0005         0.701633        0.786473  0.771690
#                         0.0010         0.702018        0.785085  0.770288
#            0.2          0.0001         0.707684        0.786385  0.771480
#                         0.0005         0.704688        0.788544  0.773445
#                         0.0010         0.705334        0.786561  0.772048
#            0.5          0.0001         0.711629        0.788742  0.773689
#                         0.0005         0.707052        0.790923  0.776276
#                         0.0010         0.708465        0.790328  0.775071
# (256, 256) 0.1          0.0001         0.707798        0.785525  0.771043
#                         0.0005         0.700836        0.783344  0.768855
#                         0.0010         0.701740        0.783939  0.769161
#            0.2          0.0001         0.707285        0.785812  0.771182
#                         0.0005         0.704453        0.783763  0.769101
#                         0.0010         0.702672        0.784710  0.770446
#            0.5          0.0001         0.709667        0.788984  0.774226
#                         0.0010             0.24      768.0
#            0.2          0.0001             0.22      768.0
#                         0.0005             0.23      768.0
#                         0.0010             0.21      768.0
#            0.5          0.0001             0.19      768.0
#                         0.0005             0.20      768.0
#                         0.0010             0.18      768.0

# %%
best_ffn_mean_history_kfold
# Out:
#    loss  accuracy        f1  \
# 0  None  0.730276  0.706933
# 0  None  0.723789  0.701380
# 0  None  0.731634  0.708531
# 0  None  0.730729  0.706746
# 0  None  0.729069  0.703504
#
#                                            f1_scores  precision  \
# 0  [0.7533748701973001, 0.5504587155963303, 0.663...   0.707048
# 0  [0.7528438469493279, 0.5442850074220682, 0.647...   0.701715
# 0  [0.7595001275184902, 0.5503018108651911, 0.658...   0.708762
# 0  [0.7581227436823104, 0.547034764826176, 0.6595...   0.706965
# 0  [0.7569741140990199, 0.5375, 0.655904842820730...   0.704219
#
#                                     precision_scores    recall  \
# 0  [0.7834773218142549, 0.526829268292683, 0.6366...  0.708786
# 0  [0.7794432548179872, 0.507380073800738, 0.6239...  0.704066
# 0  [0.7751171264966163, 0.5204567078972407, 0.637...  0.710444
# 0  [0.7827476038338658, 0.5250245338567223, 0.634...  0.708222
# 0  [0.7609903991915109, 0.5249237029501526, 0.636...  0.703743
#
#                                        recall_scores valid_loss  \
# 0  [0.7255, 0.576307363927428, 0.6935201401050788...       None
# 0  [0.728, 0.5869797225186766, 0.6730881494454174...       None
# 0  [0.7445, 0.583778014941302, 0.681260945709282,...       None
# 0  [0.735, 0.5709711846318036, 0.6870986573263281...       None
# 0  [0.753, 0.5506937033084311, 0.6760070052539404...       None
#
#    valid_accuracy  ...  hidden_dim dropout_rate  learning_rate  seed  \
# 0        0.788940  ...  (128, 128)          0.5         0.0005     0
# 0        0.791143  ...  (128, 128)          0.5         0.0005     1
# 0        0.792575  ...  (128, 128)          0.5         0.0005    12
# 0        0.791033  ...  (128, 128)          0.5         0.0005   123
# 0        0.790923  ...  (128, 128)          0.5         0.0005  1234
#
#    loss_function gamma k_fold  n_splits  batch_size  input_dim
# 0          focal     2   True         5          64        768
# 0          focal     2   True         5          64        768
# 0          focal     2   True         5          64        768
# 0          focal     2   True         5          64        768
# 0          focal     2   True         5          64        768
#
# [5 rows x 26 columns]

# %%
best_ffn_mean_history_kfold["f1"].mean()
# Out:
# 0.7054186961283366

# %%
best_ffn_mean_history_kfold["precision"].mean()
# Out:
# 0.7057416915451535

# %%
best_ffn_mean_history_kfold["recall"].mean()
# Out:
# 0.7070522984260954

# %%
np.stack(best_ffn_mean_history_kfold["f1_scores"]).mean(axis=0)
# Out:
# array([0.75616314, 0.54591606, 0.65706179, 0.86253379])

# %%
np.stack(best_ffn_mean_history_kfold["precision_scores"]).mean(axis=0)
# Out:
# array([0.77635514, 0.52092286, 0.63374112, 0.89194765])

# %%
np.stack(best_ffn_mean_history_kfold["recall_scores"]).mean(axis=0)
# Out:
# array([0.7372    , 0.573746  , 0.68219498, 0.83506822])
